# %%
#import the libraries, data, prefinal model,notice that the scaler was applied over all the data features

# %%
import pandas as pd

# %%
data = pd.read_csv('data_processed')
data
# Out:
#        HasCrCard  IsActiveMember  CreditScore       Age    Tenure   Balance  \
# 0              1               1    -0.326221  0.293517 -1.041760 -1.225848
# 1              0               1    -0.440036  0.198164 -1.387538  0.117350
# 2              1               0    -1.536794  0.293517  1.032908  1.333053
# 3              0               0     0.501521  0.007457 -1.387538 -1.225848
# 4              1               1     2.063884  0.388871 -1.041760  0.785728
# ...          ...             ...          ...       ...       ...       ...
# 15919          1               0    -1.005171  0.960302 -0.178566  0.866867
# 15920          1               0    -0.313106  1.283317 -0.350204  0.724757
# 15921          1               0    -1.939760  1.450689  0.871474 -0.672606
# 15922          1               0    -1.136104  2.437387 -0.664855 -1.225848
# 15923          1               0    -1.337519 -0.664769  0.341352 -1.225848
#
# ...

# %%
X= data.drop(['Exited'],axis=1)
y = data['Exited']

# %%
X.columns
# Out:
# Index(['HasCrCard', 'IsActiveMember', 'CreditScore', 'Age', 'Tenure',
#        'Balance', 'NumOfProducts', 'EstimatedSalary', 'Satisfaction Score',
#        'Point Earned', 'Geography_Germany', 'Geography_Spain', 'Gender_Male',
#        'Card Type_GOLD', 'Card Type_PLATINUM', 'Card Type_SILVER'],
#       dtype='object')

# %%
X.shape
# Out:
# (15924, 16)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RFC = RandomForestClassifier()

# %%
RFC.fit(X,y)
# Out:
# RandomForestClassifier()

# %%
import joblib
import pickle

# %%
with open('model_file.pkl','wb') as x_name:
    pickle.dump(RFC,x_name)
